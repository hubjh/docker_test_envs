# %%
print("test")
# Out:
# test

# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt

# 이미지 파일 경로
image_path = 'font_im.png'

# 이미지 읽기
image = cv2.imread(image_path)

# 그레이스케일 변환
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# # 이진화 (Thresholding)
# _, binary_image = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# Tesseract로 텍스트 인식
# text = pytesseract.image_to_string(binary_image, lang='kor')  # 필요에 따라 언어 코드를 변경하세요.
text = pytesseract.image_to_string(gray, lang='kor')  # 필요에 따라 언어 코드를 변경하세요.

# 인식된 텍스트 출력
print("Recognized Text:")
print(text)

# 이미지 시각화
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.show()

plt.figure(figsize=(10, 10))
plt.imshow(binary_image, cmap='gray')
plt.title('Binary Image for OCR')
plt.axis('off')
plt.show()
# Out:
# Recognized Text:
# 국가보훈부가 지방자치단체에게 6-25전쟁 및 월남전 참전유공자의 참전수당 기준을 권고하는 법 개정안을 추진한
#
# 다. 지자체별로 지급액이 달라 불거진 형평성 문제를 줄이기 위해서다.
#
# 띠
#
# 한다. 이와 별도로 각 지자체는 개별 조례에 따라 참전 수당을
#
# 보훈부는 65세 이상 참전유공자에게 참전 수당을 지
# 지급하는데, 지역에 따라 지급액이 다르다. 6월 기준 충남 서산시에 사는 유공자는 월 60만원을 받는다. 반면 경기
#
# 김포시에 사는 유공자는 8만3000원을 받는다.
#
# 보
# 계획이ㅁ
#
# 00!
#
# 부는 이번 입법예고에 대한 국민 의견을 수렴한 뒤, 국무회의 의결을 거쳐 올해 9월 국회에 개정안을 제출할
# 「

# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt

# 이미지 파일 경로
image_path = 'ts_png.png'

# 이미지 읽기
image = cv2.imread(image_path)

# 그레이스케일 변환
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Tesseract로 텍스트 인식
text = pytesseract.image_to_string(gray, lang='kor')  # 필요에 따라 언어 코드를 변경하세요.

# 인식된 텍스트 출력
print("Recognized Text:")
print(text)

# Tesseract로 박스 정보 얻기
boxes = pytesseract.image_to_boxes(gray, lang='kor')  # 각 문자에 대한 경계 상자 얻기

# 박스를 이미지에 그리기
h, w, _ = image.shape
for box in boxes.splitlines():
    box = box.split(' ')
    x, y, x2, y2 = int(box[1]), int(box[2]), int(box[3]), int(box[4])
    cv2.rectangle(image, (x, h - y), (x2, h - y2), (0, 255, 0), 2)

# 이미지 시각화
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image with Detected Text Boxes')
plt.axis('off')
plt.show()
# Out:
# Recognized Text:
# 고생  끝에 끼는 늦 꽂
#
# 버티편 지나가고 ,지나가편 소어촌
# 좋은 널 날들시.
# 삶이 너를 괴픔최더라도 슬퍼괄고
#
# 눌행이 저들 찾아와도 주저삿지 가라.
# 거센 화관어「 론들러고
#
# 차가운 비어 흠벅 졌그
#
# 뜨거운 우 살을 견며샤관
#
# 마찬내 삭시 도그
#
# 그를게 322겹게 피어난 꽂세 는
#
# 분별 셜깨라는 대가가 있다.
#
# 지름 다에거 [찾아온
#
# 무튼 곤틈과 블  채은
# 호갖과 갱븐스로 가는 과정시5
# 비록 지즌은 어두춘.를,속 씨삿일 뿐이지만
#
# 퍼지음아 당신은 병
# 아름다운 꽂을 )/올 사렸시다.
#
# 조즌깐 버타. 거의 다 왔으니까.
